# %% [markdown]
# ***HW2-1***
#
# There are two sequences in HW2_1.txt .Let the first sequence call seq1 the second one call seq2 .We want to know the longest common subsequence of seq1 and the reverse of seq2
#
# The result should contain the longest common subsequence and the length of the subsequence
#
# TO do:
#
# Please read in HW2_1.txt rather than copy paste two sequences
#
# Please write a function call rev_seq to reverse seq2
#
# Please write a function call countsub to return both answer
#
# Hint:
#
# To find the longest length of substring you can think about practice2 in pythonbasic .To find the longest substring think of the meaning of the longest length and the index of seq1,seq2
#
# Beware that there might be '\n' when you read in your file(you may also try readlines() function)
#
# ---
#
# ***Output format:***
#
# Save the result of HW2_1 as HW2_1_python_{your_name}.txt which contains a number and a sequence
#
# Maxlength:
#
# 12345
#
# Sequence:
#
# atctgac
#
# and also save the HW2_1_python_{your_name}.py/.ipynb file
#
# Email them to r11631063@ntu.edu.tw
#
# ---
#
# ***Scoring rules:***
#
# 20% Output format (using correct format to reduce my work can get all points here!)
#
# 80% Answer accuracy (depends on how many answers you perfectly match in total)
#
# ---
# **Due date**
#
# **2023.07.18 Tuesday 23:59** -> 100%
#
# 2023.07.25 Tuesday 23:59 -> 80%
#
# ...
#
#
# ---
#
#
# **Feel free to contact me via email or Slack(Huang-tien-chiung,黃天泂) if you have any problem with this homework.**
